# %%
#record mouse

import time
import Xlib.display as display

screenroot=display.Display().screen().root
pointer = screenroot.query_pointer()

#start recording after 5 seconds
time.sleep(5)

seconds = 7200
t_end = time.time() + seconds

dat = {}
i = 0

while time.time() < t_end:
    
    nextTime = time.time() + 0.03 #0.03 
    
    pointer = screenroot.query_pointer()
    data = pointer._data
    
    dat[i] = (time.time(),data["root_x"],data["root_y"])
    i = i + 1
    
    currentTime = time.time()
    while currentTime < nextTime:
        currentTime = time.time()

f = open('felix_number','w')
for t in range(i):
    f.write(str(dat[t][0]) + "," + str(dat[t][1]) + "," + str(dat[t][2]) + "\n")
f.close()

# %%
import gtk, pygtk

window = gtk.Window()
screen = window.get_screen()

x_size = screen.get_width()
y_size = screen.get_height()

# %%
#think about great models

# %%
#ted dunning model
import csv
import numpy as np

def extractFeatures(filename, n_last_timestamps_as_features = 200, normalize = True, bias = True):
    queue = {}
    
    diffTime = {}
    oldTime = -1.0
    
    maxX = 0.0
    
    x_width = float(screen.get_width()) 
    y_width = float(screen.get_height()) 

    i = 1
    with open(filename, 'r') as csvfile:
         spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
         for row in spamreader:
             if (len(row) == 3):
                    
                 timeV = float(row[0])
                
                 if (oldTime == -1):
                    oldTime = timeV
                 else:
                    diffTime[i] = timeV - oldTime
                    oldTime = timeV
                 
                 x = 0.0
                 y = 0.0
                
                 if (normalize):
                     x = float(row[1]) / x_width   
                     y = float(row[2]) / y_width
                 else:    
                     x = row[1]   
                     y = row[2] 

                 queue[i] = (timeV,x,y)  #by order (works only if input is sorted) - maybe by time??
                 i = i + 1


    featureIds = range(1, n_last_timestamps_as_features + 1)

    nFeatures = len(featureIds)*2 # times two because we have two dimensions x and y

    data = np.zeros((i - (max(featureIds)+ 1), nFeatures))
    
       
    target = np.zeros((i - (max(featureIds)+1), 2))

    for o in range(max(featureIds)+1,i):
        for u in range(0,len(featureIds)):
            data[o - max(featureIds) - 1,u*2 + 0] = queue[o - featureIds[u]][1]
            data[o - max(featureIds) - 1,u*2 + 1] = queue[o - featureIds[u]][2]

        target[o - max(featureIds) - 1,0] = queue[o][1]
        target[o - max(featureIds) - 1,1] = queue[o][2]

    
    
    print "mean difference in time step: " + str(np.mean(np.array(diffTime.values())))
    
    if (bias):
        data = np.hstack((data, np.ones((data.shape[0], 1), dtype=data.dtype)))
        
    return ((data, target))

# %%
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline


def generateModelData((data1,target1), n_last_timestamps_as_features = 200, v = False, ret = True):
    (data,target) = getMovementsOnly(data1, target1)
    N = data.shape[0]
    
    p_train = 0.6
    X_train = data[0:(N * p_train),:]
    y_train = target[0:(N * p_train),:]
    X_test = data[((N * p_train)+n_last_timestamps_as_features):N,:]
    y_test = target[((N * p_train)+n_last_timestamps_as_features):N,:]
    

    regr = linear_model.LinearRegression(normalize=True)
    
    (dtrain,tartrain) = (X_train, y_train)
    
    dist = getDistance(tartrain)


    # Train the model using the training sets
    regr.fit(dtrain, tartrain);
    
    #training error
    prediction_train = regr.predict(dtrain)
    diff_x_train = np.abs(prediction_train - tartrain)[:,0]
    diff_y_train = np.abs(prediction_train - tartrain)[:,1]
    
    print("training error - MSE: %.10f" % (np.sum((np.power(diff_x_train,2) + np.power(diff_y_train, 2))) / dtrain.shape[0]))
    
    
    (dtestn,tartestn) = (X_test, y_test)
    
    prediction_test = regr.predict(dtestn)
    
    diff_tot1 = np.abs(prediction_test - tartestn)        
    diff_x_test = diff_tot1[:,0]
    diff_y_test = diff_tot1[:,1]
    
    two_sigma = np.array([np.std(diff_x_test), np.std(diff_y_test)]) * 1
    
    
        
    if (v):
        
        plt.plot(tartestn[:,0])
        plt.plot(prediction_test[:,0])
        plt.ylabel('some numbers')
        plt.title("regression - x")
        plt.show()
        
        plt.plot(tartestn[:,1])
        plt.plot(prediction_test[:,1])
        plt.ylabel('some numbers')
        plt.title("regression - y")
        plt.show()
        
        print("MSE: %.10f" % (np.sum(np.power(diff_x_test, 2)+np.power(diff_y_test, 2)) / dtestn.shape[0]))
        print("MSE - dist: %.10f" % (np.sum(np.power(diff_x_test, 2)+np.power(diff_y_test, 2)) / dist))
        
        threshold_line = np.ones(diff_x_test.shape) * np.sum(two_sigma)
        
        print two_sigma
        
        ErrorPerTestTime = diff_x_test + diff_y_test
        
        plt.plot(ErrorPerTestTime)
        plt.plot(threshold_line)
        plt.ylabel('some numbers')
        plt.title("ErrorPerTestTime")
        plt.show()
        
        
        prediction = regr.predict(dtrain)
        
        diff_tot = np.abs(prediction - tartrain)        
        diff_x = diff_tot[:,0]
        diff_y = diff_tot[:,1]

        ErrorPerTrainTime = diff_x + diff_y
        
        threshold_line = np.ones(diff_x.shape) * np.sum(two_sigma)

        plt.plot(ErrorPerTrainTime)
        plt.plot(threshold_line)
        plt.ylabel('some numbers')
        plt.title("ErrorPerTrainTime")
        plt.show()

    if (ret):   
        final_regr = linear_model.LinearRegression(normalize=True)
    
        final_regr.fit(data, target);
    
        return ((final_regr, two_sigma))
        #return (regr, two_sigma)

# %%
def generateModel(dataFile, n_last_timestamps_as_features = 200, v = False):
    (data,target) = extractFeatures(dataFile, n_last_timestamps_as_features)
    
    return generateModelData((data,target), n_last_timestamps_as_features = n_last_timestamps_as_features, v = v)

# %%
def getMovementsOnly(data, target):
    moveOnlyData = []
    moveOnlyTarget = []
    
    first = True
    
    featuresize = data.shape[1]
    
    if (data.shape[1] % 1 == 1): # if bias term included
        featuresize -= 1
    featuresize /= 2
    
    if (featuresize > 1):
    
        for l in range(data.shape[0]):
            fcounter = 0
            for f in [0,1]:
                ccounter = 0
                for c in range(featuresize):
                    if (data[l][c*2 + f] == data[l][f]):
                        ccounter += 1
                if (ccounter == featuresize):
                    fcounter += 1

            if (fcounter < 2): #something is different
                if (first):
                    moveOnlyData = [data[l]]
                    moveOnlyTarget = [target[l]]
                    first = False
                else:
                    moveOnlyData = np.concatenate((moveOnlyData, [data[l]]), axis=0)
                    moveOnlyTarget = np.concatenate((moveOnlyTarget, [target[l]]), axis=0)

        return (np.matrix(moveOnlyData), np.matrix(moveOnlyTarget))
    else:
        return ((np.matrix(data), np.matrix(target)))

# %%
def euclidean (p1, p2):
    return np.sqrt(np.sum(np.power(p1 - p2, 2)))

def getDistance(target):
    distance = 0.0
    for t in np.arange(1, target.shape[0], 1):
        distance += euclidean(target[t,:], target[(t-1),:])
    
    return distance    

def getSmoothedDistance(target, isOverThresholdX, isOverThresholdY):
    
    distance = 0.0
    for t in np.arange(1, target.shape[0], 1):
        last_point_x = target[t-1,0]
        last_point_y = target[t-1,1]
        if (isOverThresholdX[t]):
            last_point_x = target[t,0]
        if (isOverThresholdY[t]):
            last_point_y = target[t,1]
        
        distance += (euclidean(target[t,:], np.array([last_point_x,last_point_y])) ** 2)
    
    return distance

# %%
def showStats(file, m, threshold, n_last_timestamps_as_features = 200, normalize = True):
    (fileX1, fileY1) = extractFeatures(file, 
                                     n_last_timestamps_as_features = n_last_timestamps_as_features, 
                                     normalize = normalize) 
    
    showStatsData((fileX1, fileY1), m, threshold, n_last_timestamps_as_features = n_last_timestamps_as_features)

# %%
def showStatsData((fileX, fileY), m, threshold, n_last_timestamps_as_features = 200):
    
    (newData, newTarget) = getMovementsOnly(fileX, fileY)   
    
    #distance
    dist = getDistance(newTarget)

    ErrorPerTestTime = np.sum(np.absolute(m.predict(newData) - newTarget),1);
    
    threshold_line = np.ones(ErrorPerTestTime.shape) * (threshold[0] + threshold[1])
    
    print threshold

    plt.plot(ErrorPerTestTime)
    plt.plot(threshold_line)
    plt.ylabel('prediction error')
    plt.title("tracking 10 secs")
    plt.show()
    
    plt.plot(m.predict(fileX)[:,0])
    plt.plot(fileY[:,0])
    plt.ylabel('relative x-coordinate')
    plt.title("Regression for x-coordinate")    
    plt.show()

    plt.plot(m.predict(fileX)[:,1])
    plt.plot(fileY[:,1])
    plt.ylabel('relative y-coordinate')
    plt.title("Regression for y-coordinate")
    plt.show()

    diff = np.absolute(m.predict(newData) - newTarget)#(fileX) - fileY)
    
    N = newData.shape[0]
    
    print ("MSE per 0.03s: " + str(np.sum(np.power(diff,2)) / N))
    print ("MSE per pixel move: " + str(np.sum(np.power(diff,2)) / dist))
    print ("number of records: " + str(N))
    
    print ("\nmax - |x+y|: " + str(np.max(diff)))
    print ("max - squared: " + str(np.max(np.power(diff,2))))
    
    
    newdist = getSmoothedDistance(newTarget, (diff[:,0] > threshold[0]), (diff[:,1] > threshold[1]))
    
    for l in range(len(diff)):
        change = False
        if (diff[l,0] > threshold[0]):
            diff[l,0] = 0
            change = True
        if (diff[l,1] > threshold[1]):
            diff[l,1] = 0
            change = True
        
        if (change): #if over threshold at x or y - check that
            N -= 1
            
    
    print ("übrig gebliebene slots: " + str(N))
    
    
    time_error = np.sum(np.power(diff,2)) / N
    distance_error = np.sum(np.power(diff,2)) / newdist
    
    
    print ("smoothed MSE: " + str(time_error))
    print ("smoothed MSE per dist: " + str(distance_error))
    
    if (distance_error > 0.21 or (distance_error < 0.21 and time_error > 0.00001)): 
        print ("This is not Felix - You are unauthorized!")
    else:
        print ("This is Felix - Welcome to this awesome computer!")

# %%
current_number_features = 100

(model,two_sigma) = generateModel("felix_train",n_last_timestamps_as_features=current_number_features, v = True)
# Out:
# mean difference in time step: 0.03000475079
# training error - MSE: 0.0000827856
# MSE: 0.0000815633
# MSE - dist: 0.0151394663
# [ 0.00598351  0.0062104 ]

# %%
print ("Felix validation")
showStats("felixtest2_7200sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)

# %%
mseT = {}

endFeatures = 100

for i in np.arange(1,endFeatures,1):
    mseT[i] = generateModelTest("felix_train",n_last_timestamps_as_features=i, v = False)
    print mseT[i]
    
plt.plot(range(1, endFeatures), np.array(mseT.values(), dtype=float))
plt.ylabel('mean squared error')
plt.xlabel('number of features')
#plt.title("error - features")
plt.show()

# %%
mseT = {}

r = np.arange(1,11,1)

for i in r:
    mseT[i] = generateModelTest("felix_train",n_last_timestamps_as_features=100, v = False, p_train_general = i * 0.1)
    print mseT[i]
    
plt.plot(r * 0.1, np.array(mseT.values(), dtype=float))
plt.ylabel('mean squared error')
plt.xlabel('size of the training set')
#plt.title("error - features")
plt.show()
# Out:
# mean difference in time step: 0.03000475079
# (119881, 201)
# 0.000107080753437
# mean difference in time step: 0.03000475079
# (119881, 201)
# 9.37452859732e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.71437238136e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.56322061918e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.37051035438e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.29384014329e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.25208500063e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.21742820317e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.19850493831e-05
# mean difference in time step: 0.03000475079
# (119881, 201)
# 8.15633464322e-05

# %%
mseT_big = generateModelTest("felixtest2_7200sec_1",n_last_timestamps_as_features=100, v = False, p_train_general = 0.5)
print mseT_big
# Out:
# mean difference in time step: 0.030002375188
# (239882, 201)
# 0.000145509941413

# %%
koef = np.asmatrix(model.coef_).A1

print('Coefficients: \n' + str(koef))


index = np.arange((len(koef)/2))
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

plt.bar(index, koef[0:(len(koef)/2)], bar_width, alpha=opacity, color='b')
plt.title('coefficients for x prediction')
plt.ylabel("Importance of features")
plt.show()

plt.bar(index, koef[(len(koef)/2):len(koef)], bar_width, alpha=opacity, color='b')
plt.title('coefficients for y prediction')
plt.ylabel("Importance of features")
plt.show()
# Out:
# Coefficients:
# [  1.88369440e+00  -1.42581963e-02  -7.84976609e-01   1.46527722e-02
#   -4.55668533e-01   7.75231517e-03   4.64259879e-01  -6.74518330e-03
#   -5.94271678e-02  -1.05929957e-03  -9.51076092e-02   2.95995270e-03
#    7.06063713e-02  -6.95105082e-03  -4.24064798e-02  -4.85896546e-03
#    2.51571183e-02  -1.48412278e-03  -1.41367814e-02   2.98316847e-02
#    2.41640751e-02  -2.01984071e-02  -1.46890263e-02  -1.40243026e-02
#    2.59181167e-02   2.76148200e-02  -7.12906888e-02  -4.02617781e-03
#    6.81708161e-02  -1.83175009e-02  -9.27759442e-03   1.65872822e-03
#   -3.85543626e-02   3.15092271e-03   3.36629081e-02  -4.77578193e-04
#   -1.09700794e-02   3.12523162e-02  -6.36562038e-03  -4.03374916e-02
#    1.85176053e-02   1.75351732e-02  -1.12224125e-02  -1.99569822e-04
#   -1.13507253e-02  -1.52390895e-02   1.99908633e-02   2.40543430e-02
#   -8.34157518e-03  -1.36237382e-02  -5.54392052e-03  -3.33703292e-03
#   -8.81415173e-04   5.37469022e-03   2.52997161e-02   4.27487353e-03
#   -3.45006716e-02  -9.87947316e-03   2.51484968e-02  -1.70955082e-04
#   -1.17991688e-02   7.98601907e-03  -3.61690812e-04  -1.36239014e-02
#   -5.26775568e-03   2.33878240e-02   1.30196925e-02  -9.03307372e-03
#   -6.41943513e-03   8.81415347e-05  -2.50677956e-04  -4.07576953e-03
#   -1.24389767e-03  -1.63718971e-03   6.07255980e-03  -4.39674695e-03
#   -2.12090846e-02   2.13125351e-03   3.82791257e-02   1.72219626e-02
#   -2.90714935e-02  -2.40815000e-02   9.49678689e-04   3.84031383e-03
#    3.16639392e-03   5.62222329e-03   1.04448940e-02   1.32428244e-02
#   -6.08240439e-03  -2.12980653e-02  -3.66905089e-03   1.75646959e-02
#   -4.91769335e-04  -2.55940675e-04   8.75352760e-03  -2.68890465e-02
#   -1.84804075e-03   2.56533264e-02  -9.10159737e-03  -1.79740274e-03
#    9.83251374e-04  -1.62461094e-03   1.11978853e-02  -9.90498630e-03
#    7.81321669e-04   7.66256100e-03  -1.63503727e-02   3.23049624e-04
#   -6.42506672e-03   9.07482882e-03   1.31521348e-02  -1.43994725e-02
#    1.13886964e-03  -3.17442939e-03   2.02912797e-02   1.12211723e-02
#   -3.04541614e-02  -6.33714110e-03   9.73880767e-03  -2.51959381e-03
#    1.54770931e-03   1.48227623e-02   1.40491806e-02  -2.89868248e-02
#   -4.05301815e-02   3.75308099e-02   3.62146059e-02  -8.98718677e-03
#   -1.45727871e-02  -4.90499178e-03   1.93887379e-03  -3.21778202e-02
#   -2.39896974e-02   5.32076036e-02   5.70493205e-02  -3.63921490e-02
#   -4.02966031e-02   1.11753203e-02   1.27762058e-02   1.23146140e-02
#    4.69230506e-03  -2.48887423e-02  -2.03510877e-02   2.08444329e-02
#    1.60928062e-02  -1.16101834e-02   1.15354014e-02  -4.36961678e-03
#   -2.42791930e-02   6.12635491e-03  -2.78323716e-03  -3.10772798e-03
#    2.55731744e-02   1.80387977e-02  -4.50711858e-03  -2.20998135e-02
#   -2.35046773e-02   9.81039058e-03   2.18477774e-02  -1.27174868e-03
#   -7.54725068e-03  -3.51279057e-03   3.48839448e-03   7.23653374e-03
#   -1.27341829e-02  -7.63495152e-04   1.74053038e-02  -1.69592862e-03
#   -5.45542419e-03  -6.39580658e-03  -1.44569669e-02   5.87457483e-03
#    1.58386905e-02   2.19997038e-03   5.20371083e-03  -4.06129168e-03
#   -1.63915626e-02   2.68545732e-04   4.49943574e-03   4.07745662e-03
#    6.92577212e-03  -2.89688726e-03  -2.23038854e-03   8.71901412e-05
#   -7.63266142e-03  -6.40085981e-03   1.20844189e-02   1.26187184e-02
#   -7.16966894e-03  -1.38976623e-02  -3.09940926e-03   1.54605693e-02
#    1.37307189e-02  -9.33002025e-03  -2.79860693e-02  -3.84762949e-03
#    2.30490438e-02  -2.14617733e-03  -5.09377656e-03   7.13693234e-03
#    0.00000000e+00   3.38327014e-02   1.83815607e+00  -3.46226199e-02
#   -8.24862822e-01  -4.27428621e-02  -2.06809721e-01   4.32419339e-02
#    2.87257745e-01   3.16373311e-02  -1.28548361e-01  -4.14356114e-02
#    4.44679456e-02  -1.03567918e-02  -7.08336120e-03   4.36645542e-02
#   -3.51444467e-03  -3.40068321e-02   5.95388470e-03   1.21895408e-02
#   -1.90693973e-02   1.00723398e-02   3.23998572e-02  -3.28706868e-02
#   -2.79128005e-02   4.33999703e-02   1.72511480e-02  -1.19853818e-02
#   -1.02334592e-02  -3.97634376e-02   8.20626590e-03   3.03824089e-02
#   -9.48870903e-03   1.97816166e-02   1.03477745e-02  -2.10242210e-02
#   -1.30534431e-02  -9.89422235e-03   1.13329588e-02   1.13352506e-02
#   -6.13674878e-03   6.85544708e-03  -1.82878099e-02  -1.24934015e-02
#    3.24390396e-02   9.34541176e-03  -9.00792758e-03  -7.12404964e-03
#   -9.03214196e-04   2.28742686e-05  -8.06354851e-03   6.48907912e-04
#    4.68262255e-03   3.91136520e-03  -2.63144294e-03  -6.80570929e-03
#    1.32773189e-02   1.31002231e-02  -2.10196846e-02   6.06069676e-03
#    3.13388914e-03  -3.41431737e-02   2.13429443e-02   2.39373310e-02
#   -2.51707648e-02  -3.20762392e-03   1.25681549e-02  -3.26254494e-03
#   -3.62063431e-03   5.37996836e-03  -1.31098788e-02  -1.14512345e-03
#    2.32343222e-02  -2.18662524e-02  -2.52500093e-02   4.04135988e-02
#    3.40338465e-02  -1.87422497e-02  -1.35210211e-02  -1.32231125e-02
#   -1.40030224e-02   2.00634489e-02   3.67189914e-03  -1.77644604e-02
#    2.21977646e-02   1.40681933e-02  -1.91408760e-02  -6.38201957e-03
#   -5.48896893e-04   4.62847408e-03   2.14324793e-04  -7.89271427e-03
#    1.62749881e-02   9.44543985e-03  -2.26153992e-02  -2.47991666e-03
#   -2.21373817e-03   1.04629177e-02   2.07262995e-02  -2.99067252e-02
#   -1.75545030e-02   1.84953874e-02   1.58437329e-02   7.20762399e-03
#   -1.37088902e-02  -1.75016254e-02   2.13191474e-02   1.45992849e-02
#   -2.39191572e-02   1.97006499e-03  -2.69824154e-03  -6.83286681e-03
#    1.84357547e-02   1.32443261e-03   1.12533184e-03  -1.54227237e-02
#   -1.61750689e-02   2.40729381e-02   1.27526178e-02  -1.84372452e-02
#    1.14931128e-03   1.65175791e-02  -1.59751401e-02  -1.78140939e-03
#    1.89622638e-02  -2.42153565e-02  -8.67179858e-03   1.78473346e-02
#   -2.70490684e-03   1.10891356e-02  -2.21942154e-04  -1.28160101e-02
#    9.99202313e-03  -4.09435297e-03  -4.87211705e-03   5.87312236e-03
#   -8.90374895e-03   9.21036304e-04   6.25939973e-03   1.64896224e-03
#    1.23859496e-03   6.47587767e-04  -9.13556578e-04  -4.32041974e-03
#   -8.72147565e-04  -7.19828241e-03   5.91552017e-04   1.36707068e-02
#   -4.23142932e-03  -1.10284185e-02   2.12114915e-02   8.08602970e-03
#   -3.00442181e-02  -5.59765612e-03   1.40787767e-02  -1.22595173e-02
#    1.02658632e-02   3.94313801e-02  -1.67065876e-02  -2.86459286e-02
#   -9.36574762e-04  -3.15575708e-03   1.83787960e-02   9.08562054e-03
#   -1.98204823e-02  -8.36022691e-03   6.67284858e-03   2.21497091e-02
#    8.30478327e-04  -1.93537669e-02   3.06302705e-03  -4.47240946e-03
#   -7.79340876e-04   6.00780635e-03   2.23190141e-03   5.86127192e-03
#   -2.43831937e-03  -3.13848850e-03  -4.15540722e-03  -8.36620324e-04
#    5.47278037e-03  -4.88999473e-03  -4.65150577e-03   4.23558879e-03
#   -8.80573462e-03   4.33021553e-03   2.30550251e-02  -2.08388759e-03
#   -1.56836656e-02  -7.42429384e-03   3.46551844e-03   1.19145456e-02
#    1.45277920e-02  -9.65336589e-03  -1.99672371e-02   1.47714274e-03
#    5.47830669e-03   2.66150875e-03  -8.39275819e-03  -8.91545805e-05
#    8.67491918e-03   0.00000000e+00]

# %%
print ("Felix test1")
showStats("felix4_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Felix test1
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 6.51216655454e-06
# MSE per pixel move: 0.00365090562985
# number of records: 234
#
# max - |x+y|: 0.0140788538537
# max - squared: 0.000198214125835
# übrig gebliebene slots: 223
# smoothed MSE: 2.04474317921e-06
# smoothed MSE per dist: 0.202840235891
# This is Felix - Welcome to this awesome computer!

# %%
print ("Felix test2")
showStats("felix1_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Felix test2
# mean difference in time step: 0.03003003003
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 9.4283202701e-05
# MSE per pixel move: 0.0154798141252
# number of records: 170
#
# max - |x+y|: 0.0596040160668
# max - squared: 0.00355263873129
# übrig gebliebene slots: 151
# smoothed MSE: 3.06249364873e-06
# smoothed MSE per dist: 0.0264913853702
# This is Felix - Welcome to this awesome computer!

# %%
print ("Felix test3 - lying in bed")
showStats("felix2_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Felix test3 - lying in bed
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 0.000109454085363
# MSE per pixel move: 0.017825808073
# number of records: 234
#
# max - |x+y|: 0.058579702634
# max - squared: 0.00343158156069
# übrig gebliebene slots: 204
# smoothed MSE: 4.11644294037e-06
# smoothed MSE per dist: 0.0846864657718
# This is Felix - Welcome to this awesome computer!

# %%
print ("Felix test4")
showStats("felix3_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Felix test4
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 3.13888348716e-05
# MSE per pixel move: 0.0125556147652
# number of records: 234
#
# max - |x+y|: 0.0405279215026
# max - squared: 0.00164251242132
# übrig gebliebene slots: 228
# smoothed MSE: 9.48847830686e-07
# smoothed MSE per dist: 0.0442508124675
# This is Felix - Welcome to this awesome computer!

# %%
print ("Felix test5")
showStats("felixneu_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Felix test5
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 0.000178363441545
# MSE per pixel move: 0.025248652376
# number of records: 234
#
# max - |x+y|: 0.110827900874
# max - squared: 0.0122828236121
# übrig gebliebene slots: 200
# smoothed MSE: 5.32584766536e-06
# smoothed MSE per dist: 0.108250867423
# This is Felix - Welcome to this awesome computer!

# %%
print ("Niklas test1")
showStats("niklas_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Niklas test1
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 0.000296347150636
# MSE per pixel move: 0.0179434572651
# number of records: 234
#
# max - |x+y|: 0.0900071093879
# max - squared: 0.00810127974037
# übrig gebliebene slots: 157
# smoothed MSE: 1.08257802083e-05
# smoothed MSE per dist: 0.0635621391252
# This is not Felix - You are unauthorized!

# %%
print ("Elias test1")
showStats("elias_10sec_1",model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Elias test1
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 0.000177560471223
# MSE per pixel move: 0.0253033942317
# number of records: 234
#
# max - |x+y|: 0.089188136327
# max - squared: 0.00795452366148
# übrig gebliebene slots: 203
# smoothed MSE: 5.40422259001e-06
# smoothed MSE per dist: 0.229960149247
# This is not Felix - You are unauthorized!

# %%
print ("Emely")
showStats("emely_10sec_1", model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Emely
# mean difference in time step: 0.0300000000286
# (234, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 2.5189673283e-05
# MSE per pixel move: 0.00873808457506
# number of records: 81
#
# max - |x+y|: 0.0334256877369
# max - squared: 0.00111727660069
# übrig gebliebene slots: 75
# smoothed MSE: 3.65825735362e-06
# smoothed MSE per dist: 0.669127306512
# This is not Felix - You are unauthorized!

# %%
print ("Martin")
showStats("martin_60sec", model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# Martin
# mean difference in time step: 0.0300000000143
# (1900, 201)
# [ 0.0063198   0.00621757]
# MSE per 0.03s: 2.75810636548e-05
# MSE per pixel move: 0.0119076580533
# number of records: 1339
#
# max - |x+y|: 0.0755833104624
# max - squared: 0.00571283682046
# übrig gebliebene slots: 1278
# smoothed MSE: 2.870648331e-06
# smoothed MSE per dist: 0.199220928786
# This is Felix - Welcome to this awesome computer!

# %%
#mouse didn't move at all
print ("mouse didn't move at all")
showStats("nothing_10sec_1", model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# mouse didn't move at all
# mean difference in time step: 0.0300000000286
# (234, 201)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-831-64b2047e7ce0> in <module>()
#       1 #mouse didn't move at all
#       2 print ("mouse didn't move at all")
# ----> 3 showStats("nothing_10sec_1", model, two_sigma, n_last_timestamps_as_features=current_number_features)
#
# <ipython-input-433-646bc5b9390c> in showStats(file, m, threshold, n_last_timestamps_as_features, normalize)
#       4                                      normalize = normalize)
#       5
# ----> 6     showStatsData((fileX1, fileY1), m, threshold, n_last_timestamps_as_features = n_last_timestamps_as_features)
#
# <ipython-input-819-419d7adbe4d7> in showStatsData((fileX, fileY), m, threshold, n_last_timestamps_as_features)
#       4
#       5     #distance
# ----> 6     dist = getDistance(newTarget)
#       7
#       8     ErrorPerTestTime = np.sum(np.absolute(m.predict(newData) - newTarget),1);
#
# <ipython-input-820-1a6cd5df85eb> in getDistance(target)
#       4 def getDistance(target):
#       5     distance = 0.0
# ----> 6     for t in np.arange(1, target.shape[0], 1):
#       7         distance += euclidean(target[t,:], target[(t-1),:])
#       8
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
print ("test")
showStats("test_mouse", model, two_sigma, n_last_timestamps_as_features=2, normalize = False)

# %%
test_size = 135

# %%
(data, target) = extractFeatures("martin_60sec", n_last_timestamps_as_features=current_number_features)

for i in range(data.shape[0] / test_size):
    fileX = data[(i*test_size):((i+1)*test_size),:]
    fileY = target[(i*test_size):((i+1)*test_size),:]

    showStatsData((fileX, fileY), model, two_sigma, n_last_timestamps_as_features=current_number_features)
# Out:
# mean difference in time step: 0.0300000000143
# (1900, 201)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-699fc65a59c7> in <module>()
#       5     fileY = target[(i*test_size):((i+1)*test_size),:]
#       6
# ----> 7     showStatsData((fileX, fileY), model, two_sigma, n_last_timestamps_as_features=current_number_features)
#
# <ipython-input-14-28e9ddba5b09> in showStatsData((fileX, fileY), m, threshold, n_last_timestamps_as_features)
#       4
#       5     #distance
# ----> 6     dist = getDistance(newTarget)
#       7
#       8     ErrorPerTestTime = np.sum(np.absolute(m.predict(newData) - newTarget),1);
#
# <ipython-input-12-1a6cd5df85eb> in getDistance(target)
#       4 def getDistance(target):
#       5     distance = 0.0
# ----> 6     for t in np.arange(1, target.shape[0], 1):
#       7         distance += euclidean(target[t,:], target[(t-1),:])
#       8
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
test_size = 314

(data, target) = extractFeatures("felix_train", n_last_timestamps_as_features=current_number_features)

Ni = data.shape[0]
    
X_test = data[(Ni/2):Ni,:]
y_test = target[(Ni/2):Ni,:]

c1 = 0
c2 = 0

cc3 = 0

time_array = {}
dist_array = {}

threshold = np.array(two_sigma)

print data.shape

print (data.shape[0] / test_size)

for i in range(X_test.shape[0] / test_size):
    fileX = X_test[(i*test_size):((i+1)*test_size),:]
    fileY = y_test[(i*test_size):((i+1)*test_size),:]
    
    print ("vor: " + str(fileX.shape))
    
    (newData, newTarget) = getMovementsOnly(fileX, fileY) 
    
    print ("nach: " + str(len(newData)))
    
    if (len(newData) > 1):
        
        #distance
        dist = getDistance(newTarget)

        diff = np.absolute(model.predict(newData) - newTarget)

        N = newData.shape[0]

        newdist = getSmoothedDistance(newTarget, (diff[:,0] > threshold[0]), (diff[:,1] > threshold[1]))

        for l in range(len(diff)):
            change = False
            if (diff[l,0] > threshold[0]):
                diff[l,0] = 0
                change = True
            if (diff[l,1] > threshold[1]):
                diff[l,1] = 0
                change = True

            if (change): #if over threshold at x or y - check that
                N -= 1

        if (newdist > 0):
        
            time_error = np.sum(np.power(diff,2)) / N
            distance_error = np.sum(np.power(diff,2)) / newdist


            time_array[i] = time_error
            dist_array[i] = distance_error
            
            if (distance_error > 0.0024): #0.0024
                c1 += 1
            if (time_array > 0.0000081): #0.0000081
                c2 += 1
                
            '''
            if (distance_error > 0.00251):
                if (time_error > 0.0000081):
                    print ("number of slots - failed dist test: " + str(N))
                    print ("dist error: " + str(distance_error))
                    print ("time error: " + str(time_error))
                    cc3 +=1 
            '''
            
            #if (distance_error > 0.0032 or ( distance_error > 0.0019 and distance_error < 0.0032 and time_error > 0.00001)):
            if (distance_error > 0.11 or (distance_error < 0.11 and time_error > 0.00001)): 
            
                print ("number of slots - failed dist test: " + str(N))
                print ("dist error: " + str(distance_error))
                print ("time error: " + str(time_error))
                cc3 +=1 
    
        
print("bad count - dist measure: " + str(c1) + " of " + str(X_test.shape[0] / test_size))
print("bad count - time measure: " + str(c2) + " of " + str(X_test.shape[0] / test_size))
print("bad count - combined measure: " + str(cc3) + " of " + str(X_test.shape[0] / test_size))

print("\nmax time_error: " + str(np.max(time_array.values())) )
print("\nmax distance_error: " + str(np.max(dist_array.values())) )
# Out:
# mean difference in time step: 0.03000475079
# (119881, 201)
# (119881, 201)
# 381
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 184
# number of slots - failed dist test: 160
# dist error: 0.148463435385
# time error: 5.96827252366e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 97
# number of slots - failed dist test: 91
# dist error: 0.159880210434
# time error: 3.41377822006e-06
# vor: (314, 201)
# nach: 41
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 109
# number of slots - failed dist test: 106
# dist error: 0.220128825494
# time error: 1.54097068088e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 88
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 291
# dist error: 0.233062502568
# time error: 3.34198172786e-06
# vor: (314, 201)
# nach: 33
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 79
# number of slots - failed dist test: 63
# dist error: 0.273385210061
# time error: 9.67960954924e-06
# vor: (314, 201)
# nach: 314
# vor: (314, 201)
# nach: 314
# vor: (314, 201)
# nach: 227
# number of slots - failed dist test: 210
# dist error: 0.1997595445
# time error: 4.3782495973e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 101
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 284
# dist error: 0.162487511386
# time error: 2.78264178573e-06
# vor: (314, 201)
# nach: 208
# number of slots - failed dist test: 201
# dist error: 0.19322933164
# time error: 2.77816399526e-06
# vor: (314, 201)
# nach: 223
# number of slots - failed dist test: 223
# dist error: 0.822207328068
# time error: 4.89932387632e-07
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 299
# dist error: 0.186761901594
# time error: 1.44416366862e-06
# vor: (314, 201)
# nach: 303
# vor: (314, 201)
# nach: 284
# number of slots - failed dist test: 255
# dist error: 0.114529411835
# time error: 2.79693070945e-06
# vor: (314, 201)
# nach: 204
# number of slots - failed dist test: 184
# dist error: 0.11740726334
# time error: 4.45907544137e-06
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 310
# dist error: 0.246994664978
# time error: 1.57394470006e-06
# vor: (314, 201)
# nach: 64
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 170
# number of slots - failed dist test: 163
# dist error: 0.27839960145
# time error: 3.40030443692e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 184
# number of slots - failed dist test: 175
# dist error: 0.315202425212
# time error: 2.42080813221e-06
# vor: (314, 201)
# nach: 217
# number of slots - failed dist test: 208
# dist error: 0.533852714266
# time error: 3.29307253153e-06
# vor: (314, 201)
# nach: 216
# number of slots - failed dist test: 183
# dist error: 0.170590119099
# time error: 5.31727041274e-06
# vor: (314, 201)
# nach: 94
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 93
# number of slots - failed dist test: 93
# dist error: 0.559427088518
# time error: 2.37184915597e-06
# vor: (314, 201)
# nach: 24
# vor: (314, 201)
# nach: 123
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 279
# dist error: 0.121518747555
# time error: 4.526301043e-06
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 290
# dist error: 0.159062892882
# time error: 3.05845801592e-06
# vor: (314, 201)
# nach: 184
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 228
# number of slots - failed dist test: 208
# dist error: 0.318602343546
# time error: 3.39241415133e-06
# vor: (314, 201)
# nach: 291
# vor: (314, 201)
# nach: 248
# number of slots - failed dist test: 223
# dist error: 0.11288193683
# time error: 3.81719574276e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 238
# number of slots - failed dist test: 223
# dist error: 0.258748046449
# time error: 2.75909326557e-06
# vor: (314, 201)
# nach: 314
# vor: (314, 201)
# nach: 229
# vor: (314, 201)
# nach: 232
# number of slots - failed dist test: 196
# dist error: 0.123041190101
# time error: 4.9245405852e-06
# vor: (314, 201)
# nach: 114
# number of slots - failed dist test: 101
# dist error: 0.150209075451
# time error: 4.17924483472e-06
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 309
# dist error: 0.318444860833
# time error: 1.99836149586e-06
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 310
# dist error: 0.404648671541
# time error: 1.91790386912e-06
# vor: (314, 201)
# nach: 100
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 144
# number of slots - failed dist test: 126
# dist error: 0.136714222793
# time error: 4.59489925628e-06
# vor: (314, 201)
# nach: 312
# number of slots - failed dist test: 270
# dist error: 0.115730402171
# time error: 4.47820712766e-06
# vor: (314, 201)
# nach: 68
# vor: (314, 201)
# nach: 162
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 21
# number of slots - failed dist test: 18
# dist error: 0.609514521036
# time error: 8.37386807811e-06
# vor: (314, 201)
# nach: 314
# vor: (314, 201)
# nach: 228
# number of slots - failed dist test: 213
# dist error: 0.117550997801
# time error: 3.40050555789e-06
# vor: (314, 201)
# nach: 126
# number of slots - failed dist test: 126
# dist error: 0.296777376824
# time error: 1.15805986988e-06
# vor: (314, 201)
# nach: 172
# number of slots - failed dist test: 159
# dist error: 0.147943692069
# time error: 3.72134234899e-06
# vor: (314, 201)
# nach: 314
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 285
# dist error: 0.155123855167
# time error: 3.03983444435e-06
# vor: (314, 201)
# nach: 75
# vor: (314, 201)
# nach: 167
# vor: (314, 201)
# nach: 57
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 36
# number of slots - failed dist test: 35
# dist error: 0.316717324136
# time error: 4.62734763311e-06
# vor: (314, 201)
# nach: 288
# number of slots - failed dist test: 280
# dist error: 0.157384678125
# time error: 1.65955871636e-06
# vor: (314, 201)
# nach: 166
# number of slots - failed dist test: 160
# dist error: 0.151298381654
# time error: 1.90311836059e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 218
# number of slots - failed dist test: 177
# dist error: 0.156920559099
# time error: 5.14326950002e-06
# vor: (314, 201)
# nach: 108
# number of slots - failed dist test: 103
# dist error: 0.136619007438
# time error: 1.07584986478e-06
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 47
# number of slots - failed dist test: 39
# dist error: 0.125762035015
# time error: 1.18924700967e-05
# vor: (314, 201)
# nach: 314
# number of slots - failed dist test: 305
# dist error: 0.198842168116
# time error: 1.8366855587e-06
# vor: (314, 201)
# nach: 225
# vor: (314, 201)
# nach: 239
# number of slots - failed dist test: 225
# dist error: 0.298298471547
# time error: 1.9866552891e-06
# vor: (314, 201)
# nach: 222
# number of slots - failed dist test: 206
# dist error: 0.230769158081
# time error: 2.72147324245e-06
# vor: (314, 201)
# nach: 282
# vor: (314, 201)
# nach: 110
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# vor: (314, 201)
# nach: 0
# bad count - dist measure: 60 of 190
# bad count - time measure: 60 of 190
# bad count - combined measure: 43 of 190
#
# max time_error: 1.18924700967e-05
#
# max distance_error: 0.822207328068
